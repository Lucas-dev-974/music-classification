# %% [markdown]
# **Nettoyage et récupération des donnés utiles pour l'entraînement du nouveau model**

# %%
import pandas as pd

# %%
csv_file_path = 'MSD.csv'
df = pd.read_csv(csv_file_path)

# %%
df.head()
# Out:
#    analysis_sample_rate                            audio_md5  danceability  \
# 0                 22050  b'a222795e07cd65b7a530f1346f520649'           0.0
# 1                 22050  b'bb9771eeef3d5b204a3c55e690f52a91'           0.0
# 2                 22050  b'fa329738005ca53715d9f7381a0d1fe3'           0.0
# 3                 22050  b'43cd1abd45d5a2dda16a3c65b4963bd4'           0.0
# 4                 22050  b'580a8fe08ef0f1c7734b84547d7a8bc7'           0.0
#
#     duration  end_of_fade_in  energy  idx_bars_confidence  idx_bars_start  \
# 0  218.93179           0.247     0.0                    0               0
# 1  148.03546           0.148     0.0                    0               0
# 2  177.47546           0.282     0.0                    0               0
# 3  233.40363           0.000     0.0                    0               0
# 4  209.60608           0.066     0.0                    0               0
#
#    idx_beats_confidence  idx_beats_start  ...  idx_artist_terms  \
# ...

# %% [markdown]
# ### Valeurs null
# **Il y a 10 000 valeurs au total**
#
# 3 champs ont des valeurs nulls
#
# - 'artist_latitude' : 6 258 valeurs null
# - 'artist_longitude' : 6 258 valeurs null
# - 'song_hotttnesss' : 4 352 valeurs null

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# analysis_sample_rate                 0
# audio_md5                            0
# danceability                         0
# duration                             0
# end_of_fade_in                       0
# energy                               0
# idx_bars_confidence                  0
# idx_bars_start                       0
# idx_beats_confidence                 0
# idx_beats_start                      0
# idx_sections_confidence              0
# idx_sections_start                   0
# idx_segments_confidence              0
# idx_segments_loudness_max            0
# idx_segments_loudness_max_time       0
# idx_segments_loudness_start          0
# idx_segments_pitches                 0
# idx_segments_start                   0
# idx_segments_timbre                  0
# idx_tatums_confidence                0
# idx_tatums_start                     0
# key                                  0
# key_confidence                       0
# loudness                             0
# ...

# %% [markdown]
# ### Retrait de colones sur l'artiste

# %%
non_artist_columns = [col for col in df.columns if not col.startswith('artist')]
df = df[non_artist_columns]
df.head()
# Out:
#    analysis_sample_rate                            audio_md5  danceability  \
# 0                 22050  b'a222795e07cd65b7a530f1346f520649'           0.0
# 1                 22050  b'bb9771eeef3d5b204a3c55e690f52a91'           0.0
# 2                 22050  b'fa329738005ca53715d9f7381a0d1fe3'           0.0
# 3                 22050  b'43cd1abd45d5a2dda16a3c65b4963bd4'           0.0
# 4                 22050  b'580a8fe08ef0f1c7734b84547d7a8bc7'           0.0
#
#     duration  end_of_fade_in  energy  idx_bars_confidence  idx_bars_start  \
# 0  218.93179           0.247     0.0                    0               0
# 1  148.03546           0.148     0.0                    0               0
# 2  177.47546           0.282     0.0                    0               0
# 3  233.40363           0.000     0.0                    0               0
# 4  209.60608           0.066     0.0                    0               0
#
#    idx_beats_confidence  idx_beats_start  ...  idx_artist_terms  \
# ...

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# analysis_sample_rate                 0
# audio_md5                            0
# danceability                         0
# duration                             0
# end_of_fade_in                       0
# energy                               0
# idx_bars_confidence                  0
# idx_bars_start                       0
# idx_beats_confidence                 0
# idx_beats_start                      0
# idx_sections_confidence              0
# idx_sections_start                   0
# idx_segments_confidence              0
# idx_segments_loudness_max            0
# idx_segments_loudness_max_time       0
# idx_segments_loudness_start          0
# idx_segments_pitches                 0
# idx_segments_start                   0
# idx_segments_timbre                  0
# idx_tatums_confidence                0
# idx_tatums_start                     0
# key                                  0
# key_confidence                       0
# loudness                             0
# ...

# %%
df['audio_md5']
# Out:
# 0       b'a222795e07cd65b7a530f1346f520649'
# 1       b'bb9771eeef3d5b204a3c55e690f52a91'
# 2       b'fa329738005ca53715d9f7381a0d1fe3'
# 3       b'43cd1abd45d5a2dda16a3c65b4963bd4'
# 4       b'580a8fe08ef0f1c7734b84547d7a8bc7'
#                        ...
# 9995    b'3f28a2a4bd6b99b8a0c4abe5df0d1f0e'
# 9996    b'4296453097175a6b912f20ed69875e6b'
# 9997    b'3d02c6a015112c719d87d1eea241e59c'
# 9998    b'36759353d4d181efbcddddb0076a5286'
# 9999    b'20d92b5f72cab7608a8aa94b3e145810'
# Name: audio_md5, Length: 10000, dtype: object
